# %% [markdown]
# ##**Programação e Algoritmos I**
#
# Prof. Alexandre Levada
#
# ###**Fundamentos Básicos de Computação**
#
# Iniciamos apresentando um breve histórico da computação.
#
# A história da computação pode ser dividida em 3 grandes eras.
#
#
# *   A era dos dispositivos mecânicos (500 a.C. - 1880 d.C.)
# *   A era dos dispositivos eletromecânicos (1880 d.C. - 1930 a.C.)
# *   A era dos componentes eletrônicos (1930 a.C. - hoje)
#           1.  Primeira geração: computadores a válvula
#           2.  Segunda geração: computadores transistorizados
#           3.  Terceira geração: computadores com circuitos integrados
#           4.  Quarta geração: microcomputadores
#           5.  Quinta geração: computadores portáteis
#
# Apenas na última grande era o padrão de arquitetura de computadores como conhecemos hoje foi desenvolvido.
#
# Antes, tanto os dados quanto os programas eram armazenados externamente. Por exemplo, na forma de cartões perfurados.
#
# Principais limitações:
#
# * Pouco confiável.
# * Lento e ineficaz.
# * Organização ficava por conta do operador.
# * Interface pobre.
#
# ####**O Modelo de Von Neumann**
#
# Em 1946, John Von Neumann, um matemático húngaro, revolucionou a computação ao postular 5 princípios básicos, que nortearam o desenvolvimento de novos computadores.
#
# Princípios básicos:
#
# * Execução completamente eletrônica.
# * Sistema de numeração padronizado e binário.
# * Memória interna para armazenar dados.
# * Programas armazenados para acessar e manipular os dados.
# * Universalidade: uma máquina que pudesse realizar mais que uma única tarefa, ou seja, que pudesse ser programada.
#
# ![Arquitetura.png](data:image/png;base64,...)

# %% [markdown]
# ####**Organização de um Computador**
#
# A placa mãe é a base na qual os barramentos de comunicação entre os diferentes hardwares (dispositivos) que compõem um computador são interligados. Permite a comunicação entre o processador, a memória e os dispositivos de E/S.
#
# ![Organização.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ####**Sistema de numeração binário**
#
# Aspecto fundamental para o sucesso da computação, pois permite a realização de operações e cálculos matemáticos de maneira extremamente rápida.
#
# Humanos possuem 10 dedos => sistema decimal
#
# Computadores possuem 2 estados (ligado/desligado) => sistema binário
#
# * Base Decimal: Algarismos (de 0 a 9) assumem um valor diferente (múltiplo de 10) dependendo da posição.
#
# $$
# 2562_{10} = 2 \times 10^3 + 5 \times 10^2 + 6 \times 10^1 + 2 \times 10^0
# $$
#
# * Base Binária: Algarismos (0 e 1) assumem um valor diferente (múltiplo de 2) dependendo da posição.
#
# $$
# 1101_{2} = 1 \times 2^3 + 1 \times 2^2 + 0 \times 2^1 + 1 \times 2^0
# $$
#
# *Como converter um número decimal para binário e vice-versa?*
#
# A representação de números fracionários por computadores digitais pode levar a problemas de precisão numérica. Sabemos que um número na base 10 (decimal) é representado como:
#
# $23457 = 2 \times 10^4 + 3 \times 10^3 + 4 \times 10^2 + 5 \times 10^1 + 7 \times 10^0$
#
# Analogamente, um número binário (base 2) pode ser representado como:
#
# $110101 = 1 \times 2^5 + 1 \times 2^4 + 0 \times 2^3 + 1 \times 2^2 + 0 \times 2^1 + 1 \times 2^0 = 53$
#
# O bit mais a direita é o menos significativo e portanto o seu valor é $1 \times 2^0 = 1$
#
# O segundo bit a partir da direita tem valor de $0 \times 2^1 = 0$
#
# O terceiro bit a partir da direita tem valor de $1 \times 2^2 = 4$
#
# O quarto bit a partir da direita tem valor de $0 \times 2^3 = 0$
#
# O quinto bit a partir da esquerda tem valor de $1 \times 2^4 = 16$
#
# Por fim, o bit mais a esquerda tem valor de $1 \times 2^5 = 32$
#
# Somando tudo temos: $1 + 4 + 16 + 32 = 5 + 48 = 53$
#
# Essa é a regra para convertermos um número binário para sua notação decimal.
#
# Veremos agora o processo inverso: como converter um número decimal para binário. O processo é simples. Começamos dividindo o número decimal por 2:
#
# 53 / 2 = 26 e sobra resto 1 → esse 1 será nosso bit mais a direita (menos significativo no binário)
#
# Continuamos o processo até que a divisão por 2 não seja mais possível:
#
# 26 / 2 = 13 e sobra resto 0 → esse 0 será nosso segundo bit mais a direita no binário
#
# 13 / 2 = 6 e sobra resto 1 → esse 1 será nosso terceiro bit mais a direita no binário
#
# 6 / 2 = 3 e sobra resto 0 → esse 0 será nosso quarto bit mais a direita no binário
#
# 3 / 2 = 1 e sobra resto 1 → esse 1 será nosso quinto bit mais a direita no binário
#
# 1 / 2 = 0 e sobra resto 1 → esse 1 será o nosso último bi (mais a esquerda)
#
# Note que de agora em diante não precisamos continuar com o processo pois
#
# 0 / 2 = 0 e sobra 0
# 0 / 2 = 0 e sobra 0
#
# ou seja a esquerda do sexto bit teremos apenas zeros, e como no sistema decimal, zeros a esquerda não possuem valor algum. Portanto, 53 em decimal equivale a 110101 em binário.
#
# ####**O problema da precisão numérica na computação**
#
# Com números fracionários, a ideia é similar ao visto anteriormente:
#
# Na base 10:
#
# $456,78 = 4 \times 10^2 + 5 \times 10^1 + 6 \times 10^0 + 7 \times 10^{-1} + 8 \times 10^{-2}$
#
# Na base 2:
#
# $101,101 = 1 \times 2^2 + 0 \times 2^1 + 1 \times 2^0 + 1 \times 2^{-1} + 0 \times 2^{-2} + 1 \times 2^{-2} = 4 + 1 + 0,5 + 0,125 = 5,625$
#
# Na base 10, dividir por 10 significa deslocar a vírgula uma casa para a esquerda e multiplicar por 10 significa deslocar a vírgula para direita, acrescentando ou removendo zeros quando for o caso.
#
# 2317 / 10 = 231,7
#
# 231,7 / 10 = 23,17
#
# 23,17 / 10 = 2,317
#
# Com números binários a ideia é a mesma. Mover a vírgula para a esquerda significa divisão por 2 e mover a vírgula para direita significa multiplicação por 2
#
# 28 = 11100
#
# 14 = 1110
#
# 7 = 111
#
# 3,5 = 11,1
#
# 1,75 = 1,11
#
# Para armazenar números reais em computadores, é preciso representá-los na base 2 (binário).
#
# No caso de números inteiros, a conversão é direta.
#
# 25 = 11001 pois
#
# 25 / 2 resulta em 12 com resto 1
#
# 12 / 2 resulta em 6 com resto 0
#
# 6 / 2 resulta em 3 com resto 0
#
# 3 / 2 resulta em 1 com resto 1
#
# 1 / 2 resulta em 0 com resto 1
#
# No caso de números reais, o processo é similar. Por exemplo, considere o número real:
#
# 5,625
#
# Primeiramente, devemos dividir o número em 2 partes: parte inteira e parte fracionária.
#
# A conversão é feita independentemente para cada parte. Assim, primeiro devemos converter o número 5 como segue:
#
# 5 / 2 = 2 com resto 1
#
# 2 / 2 = 1 com resto 0
#
# 1 / 2 = 1 com resto 1
#
# Então, temos que 5 = 101
#
# Em seguida iremos trabalhar com a parte fracionária: 0,625. Nesse caso ao invés de dividir por 2, iremos multiplicar por 2 a parte fracionária e tomar a parte inteira do resultado (a esquerda da vírgula), repetindo o processo até que não se tenha mais casas decimais depois da vírgula (zero).
#
# 0,625 x 2 = 1,25 → 1 (primeira casa fracionária)
#
# 0,25 x 2 = 0,5 → 0 (segunda casa)
#
# 0,5 x 2 = 1,0 → 1 (terceira casa)
#
# Assim, temos que 0,625 = 0,101 e portanto 5,625 = 101,101
#
# Porém, em alguns casos, alguns problemas podem surgir. Por exemplo, suponha que desejamos armazenar num computador o número 0,8 na base 10. Para isso, devemos proceder da forma descrita anteriormente.
#
# 0,8 x 2 = 1,6 → 1
#
# 0,6 x 2 = 1,2 → 1
#
# 0,2 x 2 = 0,4 → 0
#
# 0,4 x 2 = 0,8 → 0
#
# 0,8 x 2 = 1,6 → 1
#
# 0,6 x 2 = 1,2 → 1
#
# 0,2 x 2 = 0,4 → 0
#
# 0,4 x 2 = 0,8 → 0
#
# 0,8 x 2 = 1,6 → 1
#
# 0,6 x 2 = 1,2 → 1
#
# 0,2 x 2 = 0,4 → 0
#
# 0,4 x 2 = 0,8 → 0
# …
#
# Portanto, 0,8 = 0,110011001100110011001100….
#
# Infinitas casas decimais. Porém, como na prática temos um número finito de bits, deve-se truncar o número para uma quantidade finita. Isso implica numa aproximação. Por exemplo, qual é o erro cometido ao se representar 0,8 como 0,11001100?
#
# 1/2 + 1/4 + 1/32 + 1/64 = 51/64 = 0.796875, o que implica num erro de 0,003125.
#
# O problema pode ser amplificado ao se realizar operações matemáticas com esse valor (é como se o erro fosse sendo propagado nos cálculos). Existem outros valores para que isso ocorre: 0,2, 0,4, 0,6
#
# ####**Organização da informação na memória**
#
# Definições básicas:
#
# * **Bit:** é a unidade básica da informação em um computador. Um bit pode assumir apenas um de dois valores: 0 ou 1
#
# * **Byte:** é um conjunto de 8 bits, por exemplo, 01101110.
#
# * **Palavra:** é a menor subdivisão da memória de um computador, sendo que cada palavra possui um endereço de memória. O tamanho da palavra é determinado pelo número de bits (i.e., 16, 32, 64 bits).
#
# * **Memória:** é onde são armazenados os dados e as instruções de um programa que está sendo executado.
#
# A memória de um computador compara-se a um armário com várias gavetas. Cada uma possui uma posição específica dentro do armário (endereço único), o que permite sua rápida localização. Cada gaveta armazena alguma coisa (dados ou instruções de programas). Há gavetas para dados e há gavetas para instruções (como por exemplo, *mova o conteúdo da gaveta X para a gaveta Y*). O tamanho máximo da informação que cada gaveta pode armazenar é definido pelo **tamanho da palavra**. Tipicamente, nos computadores atuais, cada posição de memória equivale a **64 bits**.
#
# As figuras a seguir ilustram uma parte dos endereços de memória e seu conteúdo. Um programa executado pelo computador é uma sequência de 0's e 1's que corresponde a uma sequência de intruções que ele deve executar.
#
# ![memoria.png](data:image/png;base64,...)

# %% [markdown]
# ![programa.png](data:image/png;base64,...)

# %% [markdown]
# ####**Interface Hardware/Software**
#
# As perguntas que surgem naturalmente neste momento são:
#
# * Como gerenciar toda essas informações ?
# * Como escrever programas nesse esquema de gavetas ?
# * Precisamos realmente escrever tudo com 0's e 1's ?
# * Precisamos saber o local exato de cada dado na memória ?
#
# Apesar do hardware executar apenas instruções simples de baixo nível, dois componentes são fundamentais para o gerenciamento e o desenvolvimento de aplicações:
#
# * Sistemas Operacionais
# * Compliadores
#
# **Modelos de Camadas Hierárquicas**
#
# ![camadas.png](data:image/png;base64,...)

# %% [markdown]
# ####**Sistema Operacional**
#
# É um tipo de software vital pois trata-se da principal interface entre o hardware e o software. (Windows, Linux, Mac OS, Android,...)
#
# Um S.O. realiza duas funções básicas:
#
# 1. Atuar como uma máquina virtual
#       * Encapsular todo hardware do programador de modo a oferecer uma interface simples e acessível aos recursos da máquina
#
# 2. Atuar como um gerenciador de recursos
#       * Compartilhamento de recursos em tempo e espaço
#       * Memória é limitada mas diversos programas precisam ser executados
#       * Mediador de conflitos por recursos
#
# ####**Linguagens de Programação de Alto Nível**
#
# Desempenham um papel fundamental na programação de computadores, pois trazem uma série de benefícios, como:
#
# 1. Desenvolvimento de programas torna-se muito mais rápido (codificação mais fácil)
# 2. Facilita a manutenção do software
# 3. Aumentam a portabilidade (independência do código de máquina)
#
# Mas, se programas são simples conjuntos de instruções para o computador, então porque simplesmente não utilizamos o português ou inglês para escrevê-los?
#
# ####* Falta de rigidez sintática e semântica: Ambiguidade!
# ####* Solução: Linguagens Formais
#
# ####**O Compilador**
#
# É um programa que faz a tradução de uma linguagem de alto nível para assembly (linguagem de baixo nível dependente do processador e que define mneumônicos para os códigos binários) ou linguagem intermediária.

# %% [markdown]
# ![traducao.png](data:image/png;base64,...)

# %% [markdown]
# ####**A Linguagem Python**
#
# * Trata-se de uma linguagem de alto nível independente de plataforma (alta portabilidade)
# * Programas escritos em Python rodam em qualquer S.O. (windows, linux, MacOS,...). Porque ?
# * A linguagem é interpretada!
#   * Vantagem: o mesmo código roda em qualquer sistema operacional!
#   * Desvantagem: execução mais lenta.
#
# Porque é um pouco mais lento? Um compilador Python traduz a linguagem de alto nível para um código intermediário (Bytecode). Depois, uma máquina virtual executa esse código intermediário, realizando uma tradução em tempo real. Não há geração de um arquivo executável binário empacotando o código de máquina.
#
# ![Python_Interpreter.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Link para ambiente Google Colab: https://colab.research.google.com/drive/1hB2TRXlwlfj7_IDggZQqJrx75XW3YWye?usp=sharing
#
# "No mundo só existem 10 tipos de pessoas, as que conhecem binário e as que não conhecem." (Autor Anônimo)
